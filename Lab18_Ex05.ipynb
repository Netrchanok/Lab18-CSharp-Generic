// %% [markdown]
// # Lab 18 Exercise 5

// %% [markdown]
// ## Generic static method

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab18_Ex05
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // Generic static method
//
// int a = 20, b = 30;
// System.Console.WriteLine($"Before Swap: a = {a}, b = {b}");
// Swap<int>(ref a, ref b);
// System.Console.WriteLine($"After Swap:  a = {a}, b = {b}");
//
// string h = "Hello", w = "World";
// System.Console.WriteLine($"Before Swap: h = {h}, w = {w}");
// Swap<string>(ref h, ref w);
// System.Console.WriteLine($"After Swap:  h = {h}, w = {w}");
//
// static void Swap<T>(ref T a, ref T b)
// {
//     T temp;
//     temp = a;
//     a = b;
//     b = temp;
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab18_Ex05
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab18_Ex05
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// Swap เป็นฟังก์ชันแบบ generic ที่สามารถใช้กับหลายประเภทของข้อมูล
//
// ใช้ ref เพื่อให้ค่าของตัวแปรถูกเปลี่ยนจริง
//
// สามารถใช้งานได้ทั้ง int, string หรือประเภทอื่น ๆ
